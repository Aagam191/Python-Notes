# %% [markdown]
# WAP to reduce fraction 8/24 to 1/3

# %%
num=int(68)
den=int(156)
flag=0
for i in range(num,1,-1):
    if num % i == 0:
        flag=1
        if flag==1:
         if den%i==0:
            den=den//i
            num=num//i
         else:
            pass
    else:
        flag=0

print("Reduced Fraction-->",num,"/",den)
# Out:
# Reduced Fraction--> 17 / 39

# %% [markdown]
# Disarium number

# %% [markdown]
# Compute the value of a+aa+aaa+aaaa

# %%
a=9
a=a+(a*10+a)+((a*100)+(a*10+a))+((a*1000)+(a*100)+(a*10+a))
print(a)
# Out:
# 11106

# %% [markdown]
# Colltaz sequence is generated by repeatedly applying the following rules to an integer and then to each resulting integer integer in turn
# If even/2
# If odd*3 + 1
# This algo is tested and found to always reach one for all positive integers

# %% [markdown]
# Create a function that takes two integers a and b and returns number a if it took fewer steps to reach 1 than  b

# %%
a=int(input("Enter number"))
temp=a
while temp>0:
    r=temp%10
    sum=sum+r
    temp=temp%10
if((a/2)==sum):
    print("yes")
else:
    print("no")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-8344fd82d213> in <module>
#       3 while temp>0:
#       4     r=temp%10
# ----> 5     sum=sum+r
#       6     temp=temp%10
#       7 if((a/2)==sum):
#
# TypeError: unsupported operand type(s) for +: 'builtin_function_or_method' and 'int'
